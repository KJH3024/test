# 4  201803  41537532000000  6359239000000  1245929000000  2585189000000
#
#          전국_슈퍼마켓        전국_편의점        전국_면세점  전국_전자상거래/통신판매        전국_식료품  \
# 0  1695525000000  588203000000  165761000000  5903889000000  674438000000
# 1  1740304000000  583542000000  157946000000  5887567000000  724332000000
# 2  1814588000000  586461000000  168908000000  6151384000000  681332000000
# 3  1755273000000  528137000000  141917000000  5496556000000  829931000000
# 4  1753249000000  616841000000  158031000000  6255475000000  645898000000
#
#    ...       전국_오락/문화   전국_스포츠/오락/여가      전국_서적/문구          전국_교육  \
# 0  ...  1331441000000  1074265000000  257176000000   951296000000
# 1  ...  1247976000000   944550000000  303426000000  1017197000000
# 2  ...  1103646000000   835011000000  268635000000  1037402000000
# 3  ...   984467000000   736093000000  248374000000   994975000000
# 4  ...  1362501000000   995555000000  366946000000  1127710000000
#
#         전국_숙박/음식         전국_숙박         전국_음식점  전국_공과금/개인 및 전문 서비스  \
# 0  4446595000000  229198000000  4217396000000       3784621000000
# 1  5029593000000  270430000000  4759164000000       3742694000000
# 2  4715788000000  265792000000  4449996000000       4716929000000
# 3  4063180000000  210310000000  3852870000000       3554140000000
# 4  4748810000000  216617000000  4532193000000       3926555000000
#
#         전국_금융/보험          전국_기타
# 0  1499742000000  2940933000000
# 1  1561194000000  3040014000000
# 2  1537239000000  2998166000000
# 3  1403030000000  2818422000000
# 4  1640415000000  3120761000000
#
# [5 rows x 42 columns]

# %%
# 괄호 제거 및 int64로 변경
credit_sum_df["전국_항공사"] = credit_sum_df["전국_항공사"].str.replace("\(", "-")
credit_sum_df["전국_항공사"] = credit_sum_df["전국_항공사"].str.replace("\)", "")
credit_sum_df["전국_항공사"] = credit_sum_df["전국_항공사"].astype('int64')
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\2960496992.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   credit_sum_df["전국_항공사"] = credit_sum_df["전국_항공사"].str.replace("\(", "-")
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\2960496992.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   credit_sum_df["전국_항공사"] = credit_sum_df["전국_항공사"].str.replace("\)", "")

# %%
# 억단위만 남기기
credit_sum_df.iloc[:, 1:] = (credit_sum_df.iloc[:, 1:]/1000000)
credit_sum_df.iloc[:, 1:] = credit_sum_df.iloc[:, 1:].astype(int)
credit_sum_df.head()
# Out:
#        날짜     전국_합계  전국_종합소매   전국_백화점  전국_대형마트/유통전문점  전국_슈퍼마켓  전국_편의점  전국_면세점  \
# 0  201711  39955806  6574562  1510547        2614526  1695525  588203  165761
# 1  201712  40943757  6633992  1505431        2646769  1740304  583542  157946
# 2  201801  40918563  6411773  1221065        2620752  1814588  586461  168908
# 3  201802  36782205  6180054  1147367        2607360  1755273  528137  141917
# 4  201803  41537532  6359239  1245929        2585189  1753249  616841  158031
#
#    전국_전자상거래/통신판매  전국_식료품  ...  전국_오락/문화  전국_스포츠/오락/여가  전국_서적/문구    전국_교육  \
# 0        5903889  674438  ...   1331441       1074265    257176   951296
# 1        5887567  724332  ...   1247976        944550    303426  1017197
# 2        6151384  681332  ...   1103646        835011    268635  1037402
# 3        5496556  829931  ...    984467        736093    248374   994975
# 4        6255475  645898  ...   1362501        995555    366946  1127710
#
#    전국_숙박/음식   전국_숙박   전국_음식점  전국_공과금/개인 및 전문 서비스  전국_금융/보험    전국_기타
# 0   4446595  229198  4217396             3784621   1499742  2940933
# 1   5029593  270430  4759164             3742694   1561194  3040014
# 2   4715788  265792  4449996             4716929   1537239  2998166
# 3   4063180  210310  3852870             3554140   1403030  2818422
# 4   4748810  216617  4532193             3926555   1640415  3120761
#
# [5 rows x 42 columns]

# %%
df1 = credit_sum_df[['날짜','전국_건강보조식품']]
df1['전국_건강보조식품_등락률'] = credit_sum_df['전국_건강보조식품'].pct_change().round(2)
df1['전국_의료/보건'] = credit_sum_df['전국_의료/보건']
df1['전국_의료/보건_등락률'] = credit_sum_df['전국_의료/보건'].pct_change().round(2)
df1['전국_종합병원'] = credit_sum_df['전국_종합병원']
df1['전국_종합병원_등락률'] = credit_sum_df['전국_종합병원'].pct_change().round(2)
df1['전국_일반병의원/기타의료기관'] = credit_sum_df['전국_일반병의원/기타의료기관']
df1['전국_일반병의원/기타의료기관_등락률'] = credit_sum_df['전국_일반병의원/기타의료기관'].pct_change().round(2)
df1.head()
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\1266039890.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['전국_건강보조식품_등락률'] = credit_sum_df['전국_건강보조식품'].pct_change().round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\1266039890.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['전국_의료/보건'] = credit_sum_df['전국_의료/보건']
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\1266039890.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['전국_의료/보건_등락률'] = credit_sum_df['전국_의료/보건'].pct_change().round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\1266039890.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['전국_종합병원'] = credit_sum_df['전국_종합병원']
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\1266039890.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['전국_종합병원_등락률'] = credit_sum_df['전국_종합병원'].pct_change().round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\1266039890.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['전국_일반병의원/기타의료기관'] = credit_sum_df['전국_일반병의원/기타의료기관']
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\1266039890.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['전국_일반병의원/기타의료기관_등락률'] = credit_sum_df['전국_일반병의원/기타의료기관'].pct_change().round(2)
#        날짜  전국_건강보조식품  전국_건강보조식품_등락률  전국_의료/보건  전국_의료/보건_등락률  전국_종합병원  \
# 0  201711      64328            NaN   3067709           NaN   687531
# 1  201712      66216           0.03   3259965          0.06   715653
# 2  201801      59969          -0.09   3324266          0.02   720011
# 3  201802      83924           0.40   2874333         -0.14   609160
# 4  201803      64525          -0.23   3255285          0.13   692623
#
#    전국_종합병원_등락률  전국_일반병의원/기타의료기관  전국_일반병의원/기타의료기관_등락률
# 0          NaN          2380178                  NaN
# 1         0.04          2544313                 0.07
# 2         0.01          2604254                 0.02
# 3        -0.15          2265173                -0.13
# 4         0.14          2562662                 0.13

# %%
df2 = credit_sum_df[['날짜','전국_서적/문구']]
df2['전국_서적/문구_등락률'] = credit_sum_df['전국_서적/문구'].pct_change().round(2)
df2['전국_교육'] = credit_sum_df['전국_교육']
df2['전국_교육_등락률'] = credit_sum_df['전국_교육'].pct_change().round(2)
df2['전국_공과금/개인 및 전문 서비스'] = credit_sum_df['전국_공과금/개인 및 전문 서비스']
df2['전국_공과금/개인 및 전문 서비스_등락률'] = credit_sum_df['전국_공과금/개인 및 전문 서비스'].pct_change().round(2)
df2['전국_금융/보험'] = credit_sum_df['전국_금융/보험']
df2['전국_금융/보험_등락률'] = credit_sum_df['전국_금융/보험'].pct_change().round(2)
df2['전국_기타'] = credit_sum_df['전국_기타']
df2['전국_기타_등락률'] = credit_sum_df['전국_기타'].pct_change().round(2)
df2.head()
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\3447956424.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['전국_서적/문구_등락률'] = credit_sum_df['전국_서적/문구'].pct_change().round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\3447956424.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['전국_교육'] = credit_sum_df['전국_교육']
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\3447956424.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['전국_교육_등락률'] = credit_sum_df['전국_교육'].pct_change().round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\3447956424.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['전국_공과금/개인 및 전문 서비스'] = credit_sum_df['전국_공과금/개인 및 전문 서비스']
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\3447956424.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['전국_공과금/개인 및 전문 서비스_등락률'] = credit_sum_df['전국_공과금/개인 및 전문 서비스'].pct_change().round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\3447956424.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['전국_금융/보험'] = credit_sum_df['전국_금융/보험']
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\3447956424.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['전국_금융/보험_등락률'] = credit_sum_df['전국_금융/보험'].pct_change().round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\3447956424.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['전국_기타'] = credit_sum_df['전국_기타']
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\3447956424.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['전국_기타_등락률'] = credit_sum_df['전국_기타'].pct_change().round(2)
#        날짜  전국_서적/문구  전국_서적/문구_등락률    전국_교육  전국_교육_등락률  전국_공과금/개인 및 전문 서비스  \
# 0  201711    257176           NaN   951296        NaN             3784621
# 1  201712    303426          0.18  1017197       0.07             3742694
# 2  201801    268635         -0.11  1037402       0.02             4716929
# 3  201802    248374         -0.08   994975      -0.04             3554140
# 4  201803    366946          0.48  1127710       0.13             3926555
#
#    전국_공과금/개인 및 전문 서비스_등락률  전국_금융/보험  전국_금융/보험_등락률    전국_기타  전국_기타_등락률
# 0                     NaN   1499742           NaN  2940933        NaN
# 1                   -0.01   1561194          0.04  3040014       0.03
# 2                    0.26   1537239         -0.02  2998166      -0.01
# 3                   -0.25   1403030         -0.09  2818422      -0.06
# 4                    0.10   1640415          0.17  3120761       0.11

# %%
cpi_df = pd.read_csv('./csv/소비자물가지수_2020100__20220809134223.csv', encoding='CP949')
cpi_df
# Out:
#          시점       전국
# 0   2017.11   97.347
# 1   2017.12   97.698
# 2   2018.01   98.106
# 3   2018.02   98.855
# 4   2018.03   98.751
# 5   2018.04   98.931
# 6   2018.05   98.979
# 7   2018.06   98.779
# 8   2018.07   98.590
# 9   2018.08   99.462
# 10  2018.09  100.221
# 11  2018.10  100.041
# 12  2018.11   99.330
# 13  2018.12   98.988
# 14  2019.01   98.884
# 15  2019.02   99.311
# 16  2019.03   99.121
# 17  2019.04   99.481
# 18  2019.05   99.652
# 19  2019.06   99.491
# 20  2019.07   99.187
# 21  2019.08   99.425
# 22  2019.09   99.794
# 23  2019.10  100.041
# 24  2019.11   99.481
# 25  2019.12   99.719
# 26  2020.01  100.090
# 27  2020.02  100.160
# 28  2020.03   99.940
# 29  2020.04   99.500
# 30  2020.05   99.440
# 31  2020.06   99.710
# 32  2020.07   99.630
# 33  2020.08  100.190
# 34  2020.09  100.740
# 35  2020.10  100.180
# 36  2020.11  100.090
# 37  2020.12  100.330
# 38  2021.01  101.040
# 39  2021.02  101.580
# 40  2021.03  101.840
# 41  2021.04  101.980
# 42  2021.05  102.050
# 43  2021.06  102.050
# 44  2021.07  102.260
# 45  2021.08  102.750
# 46  2021.09  103.170
# 47  2021.10  103.350
# 48  2021.11  103.870
# 49  2021.12  104.040
# 50  2022.01  104.690
# 51  2022.02  105.300
# 52  2022.03  106.060
# 53  2022.04  106.850
# 54  2022.05  107.560
# 55  2022.06  108.220
# 56  2022.07  108.740

# %%
cpi_df["CPI_등락률"] = cpi_df["전국"].pct_change()
cpi_df = cpi_df.iloc[1:-3]
cpi_df.tail(2)
# Out:
#          시점      전국   CPI_등락률
# 52  2022.03  106.06  0.007217
# 53  2022.04  106.85  0.007449

# %%
cpi_df["시점"] = cpi_df["시점"].astype(str)

# .10 이 .1로 변환된 걸 다시 재변환

cpi_df["시점"][cpi_df["시점"].str.endswith(".1")] = cpi_df["시점"][cpi_df["시점"].str.endswith(".1")]+"0"
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\2535207010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_df["시점"] = cpi_df["시점"].astype(str)
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\2535207010.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_df["시점"][cpi_df["시점"].str.endswith(".1")] = cpi_df["시점"][cpi_df["시점"].str.endswith(".1")]+"0"

# %%
# 날짜로 형변환 후 인덱스로 설정

cpi_df["시점"] = pd.to_datetime(cpi_df["시점"], format="%Y.%m")
cpi_df["시점"] = cpi_df["시점"].dt.strftime('%Y-%m')
cpi_df.rename(columns={"시점" : "날짜"}, inplace=True)
cpi_df.set_index("날짜", inplace=True)
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\291212830.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_df["시점"] = pd.to_datetime(cpi_df["시점"], format="%Y.%m")
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\291212830.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_df["시점"] = cpi_df["시점"].dt.strftime('%Y-%m')
# C:\Users\82104\AppData\Local\Temp\ipykernel_7812\291212830.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpi_df.rename(columns={"시점" : "날짜"}, inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

####### 설정하기 ###
title = "소비자물가지수와 전국 건강 신용카드 승인"
left_ax = df1[['전국_건강보조식품','전국_의료/보건','전국_종합병원','전국_일반병의원/기타의료기관']]
right_ax = cpi_df['전국']



fig, ax0 = plt.subplots(figsize = (20, 10))
ax1 = ax0.twinx()
plt.rc('font', family='Malgun Gothic')              # 한글 깨짐 오류 수정

# 그래프 생성
left_ax.plot(kind = 'bar', stacked = True, ax = ax0,)
plt.legend(bbox_to_anchor=(1,1))
right_ax.plot(kind ='line', secondary_y = True, ax = ax1,color='r',marker = 'o')

plt.title(title, fontsize = 20)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

fig, ax1 = plt.subplots(figsize=(20,10))
plt.xticks(rotation=90)

df1[["전국_건강보조식품_등락률", "전국_의료/보건_등락률", "전국_종합병원_등락률","전국_일반병의원/기타의료기관_등락률"]].plot(kind='bar', stacked=True, label="전국 건강 등락률", ax=ax1)
ax1.set_ylabel("개인 신용카드 소비금액")
plt.legend(loc="upper left")  

ax2 = ax1.twinx()
cpi_df["CPI_등락률"].plot(kind='line', marker='o' , color="m", label="CPI 등락률", ax=ax2)

ax2.set_ylabel("소비자 물가 지수")

plt.title("CPI와 전국 건강 등락률")
plt.legend(loc="upper right")  
plt.show()

# %%
total_he_cpi_df = pd.DataFrame()

total_he_cpi_df["날짜"] = df["날짜"]
total_he_cpi_df["전국_건강보조식품_등락률"] = df1["전국_건강보조식품_등락률"]
total_he_cpi_df["전국_의료/보건_등락률"] = df1["전국_의료/보건_등락률"]
total_he_cpi_df["전국_종합병원_등락률"] = df1["전국_종합병원_등락률"]
total_he_cpi_df["전국_일반병의원/기타의료기관_등락률"] = df1["전국_일반병의원/기타의료기관_등락률"]
total_he_cpi_df["CPI_등락률"] = cpi_df["CPI_등락률"]
total_he_cpi_df.head()
# Out:
#        날짜  전국_건강보조식품_등락률  전국_의료/보건_등락률  전국_종합병원_등락률  전국_일반병의원/기타의료기관_등락률  \
# 0  201711            NaN           NaN          NaN                  NaN
# 1  201712           0.03          0.06         0.04                 0.07
# 2  201801          -0.09          0.02         0.01                 0.02
# 3  201802           0.40         -0.14        -0.15                -0.13
# 4  201803          -0.23          0.13         0.14                 0.13
#
#     CPI_등락률
# 0       NaN
# 1  0.003606
# 2  0.004176
# 3  0.007635
# 4 -0.001052

# %%
sns.heatmap(total_he_cpi_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

####### 설정하기 ###
title = "소비자물가지수와 전국 기타 신용카드 승인"
left_ax = df2[['전국_서적/문구','전국_교육','전국_공과금/개인 및 전문 서비스','전국_금융/보험','전국_기타']]
right_ax = cpi_df['전국']



fig, ax0 = plt.subplots(figsize = (20, 10))
ax1 = ax0.twinx()
plt.rc('font', family='Malgun Gothic')              # 한글 깨짐 오류 수정

# 그래프 생성
left_ax.plot(kind = 'bar', stacked = True, ax = ax0,)
plt.legend(bbox_to_anchor=(1,1))
right_ax.plot(kind ='line', secondary_y = True, ax = ax1,color='r',marker = 'o')

plt.title(title, fontsize = 20)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

fig, ax1 = plt.subplots(figsize=(20,10))
plt.xticks(rotation=90)

df2[['전국_서적/문구_등락률','전국_교육_등락률','전국_공과금/개인 및 전문 서비스_등락률','전국_금융/보험_등락률','전국_기타_등락률']].plot(kind='bar', stacked=True, label="전국 기타 등락률", ax=ax1)
ax1.set_ylabel("개인 신용카드 소비금액")
plt.legend(loc="upper left")  

ax2 = ax1.twinx()
cpi_df["CPI_등락률"].plot(kind='line', marker='o' , color="m", label="CPI 등락률", ax=ax2)

ax2.set_ylabel("소비자 물가 지수")

plt.title("CPI와 전국 기타 등락률")
plt.legend(loc="upper right")  
plt.show()

# %%
total_gi_cpi_df = pd.DataFrame()

total_gi_cpi_df["날짜"] = df["날짜"]
total_gi_cpi_df["전국_서적/문구_등락률"] = df2["전국_서적/문구_등락률"]
total_gi_cpi_df["전국_교육_등락률"] = df2["전국_교육_등락률"]
total_gi_cpi_df["전국_공과금/개인 및 전문 서비스_등락률"] = df2["전국_공과금/개인 및 전문 서비스_등락률"]
total_gi_cpi_df["전국_금융/보험_등락률"] = df2["전국_금융/보험_등락률"]
total_gi_cpi_df["전국_기타_등락률"] = df2["전국_기타_등락률"]
total_gi_cpi_df["CPI_등락률"] = cpi_df["CPI_등락률"]
total_gi_cpi_df.head()
# Out:
#        날짜  전국_서적/문구_등락률  전국_교육_등락률  전국_공과금/개인 및 전문 서비스_등락률  전국_금융/보험_등락률  \
# 0  201711           NaN        NaN                     NaN           NaN
# 1  201712          0.18       0.07                   -0.01          0.04
# 2  201801         -0.11       0.02                    0.26         -0.02
# 3  201802         -0.08      -0.04                   -0.25         -0.09
# 4  201803          0.48       0.13                    0.10          0.17
#
#    전국_기타_등락률   CPI_등락률
# 0        NaN       NaN
# 1       0.03  0.003606
# 2      -0.01  0.004176
# 3      -0.06  0.007635
# 4       0.11 -0.001052

# %%
sns.heatmap(total_gi_cpi_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# 계절 나누는 함수
def seasons(s):
    if s.endswith("3") or s.endswith("4") or s.endswith("5"):
        return "봄"
    elif s.endswith("6") or s.endswith("7") or s.endswith("8"):
        return "여름"
    elif s.endswith("9") or s.endswith("10") or s.endswith("11"):
        return "가을"
    else:
        return "겨울"

# %%
# str 타입이 아니면 함수를 적용 못하기 때문에 데이터 타입 변경
total_he_cpi_df["날짜"] = total_he_cpi_df["날짜"].astype(str)

# %%
# 계졀 나누는 함수 적용
total_he_cpi_df["계절"] = total_he_cpi_df["날짜"].apply(seasons)
total_he_cpi_df.head()
# Out:
#        날짜  전국_건강보조식품_등락률  전국_의료/보건_등락률  전국_종합병원_등락률  전국_일반병의원/기타의료기관_등락률  \
# 0  201711            NaN           NaN          NaN                  NaN
# 1  201712           0.03          0.06         0.04                 0.07
# 2  201801          -0.09          0.02         0.01                 0.02
# 3  201802           0.40         -0.14        -0.15                -0.13
# 4  201803          -0.23          0.13         0.14                 0.13
#
#     CPI_등락률  계절
# 0       NaN  가을
# 1  0.003606  겨울
# 2  0.004176  겨울
# 3  0.007635  겨울
# 4 -0.001052   봄

# %%
# 날짜로 형변환 후 인덱스로 설정

total_he_cpi_df["날짜"] = pd.to_datetime(total_he_cpi_df["날짜"], format="%Y%m")
total_he_cpi_df["날짜"] = total_he_cpi_df["날짜"].dt.strftime('%Y-%m')
total_he_cpi_df.rename(columns={"시점" : "날짜"}, inplace=True)
total_he_cpi_df.set_index("날짜", inplace=True)

# %%
plt.figure(figsize=(20,10))

y = total_he_cpi_df[["전국_건강보조식품_등락률", "전국_의료/보건_등락률", "전국_종합병원_등락률","전국_일반병의원/기타의료기관_등락률","CPI_등락률"]]


total_he_cpi_df[total_he_cpi_df["계절"]=="겨울"].plot()
plt.show()

# %%
total_gi_cpi_df["날짜"] = total_gi_cpi_df["날짜"].astype(str)
total_gi_cpi_df["계절"] = total_gi_cpi_df["날짜"].apply(seasons)
total_gi_cpi_df.head()
# Out:
#        날짜  전국_서적/문구_등락률  전국_교육_등락률  전국_공과금/개인 및 전문 서비스_등락률  전국_금융/보험_등락률  \
# 0  201711           NaN        NaN                     NaN           NaN
# 1  201712          0.18       0.07                   -0.01          0.04
# 2  201801         -0.11       0.02                    0.26         -0.02
# 3  201802         -0.08      -0.04                   -0.25         -0.09
# 4  201803          0.48       0.13                    0.10          0.17
#
#    전국_기타_등락률   CPI_등락률  계절
# 0        NaN       NaN  가을
# 1       0.03  0.003606  겨울
# 2      -0.01  0.004176  겨울
# 3      -0.06  0.007635  겨울
# 4       0.11 -0.001052   봄

# %%
# 날짜로 형변환 후 인덱스로 설정

total_gi_cpi_df["날짜"] = pd.to_datetime(total_gi_cpi_df["날짜"], format="%Y%m")
total_gi_cpi_df["날짜"] = total_gi_cpi_df["날짜"].dt.strftime('%Y-%m')
total_gi_cpi_df.rename(columns={"시점" : "날짜"}, inplace=True)
total_gi_cpi_df.set_index("날짜", inplace=True)

# %%
plt.figure(figsize=(20,10))
x = total_gi_cpi_df["날짜"]
y = total_gi_cpi_df[['전국_서적/문구_등락률','전국_교육_등락률','전국_공과금/개인 및 전문 서비스_등락률','전국_금융/보험_등락률','전국_기타_등락률','CPI_등락률']]


total_gi_cpi_df[total_gi_cpi_df["계절"]=="겨울"].plot()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,10))


x = total_he_cpi_df.index
y = total_he_cpi_df["전국_건강보조식품_등락률"]

ymin, ymax = plt.ylim([total_he_cpi_df["전국_건강보조식품_등락률"].min(), total_he_cpi_df["전국_건강보조식품_등락률"].max()])

plt.fill_between(x[0:4], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[3:7], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[6:10], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[9:13], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[12:16], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[15:19], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[18:22], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[21:25], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[24:28], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[27:31], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[30:34], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[33:37], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[36:40], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[39:43], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[42:46], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[45:49], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[48:52], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[51:55], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[54:58], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[57:], ymin, ymax, color='saddlebrown', alpha=0.5)

# plt.plot(total_acco_cpi_df["전국_숙박_등락률"], color='darkslateblue')
total_he_cpi_df["전국_건강보조식품_등락률"].plot(color='darkslateblue', marker='s', ax=ax1)

plt.title("전국_건강보조식품_등락률")
plt.xlabel("날짜")
ax1.set_ylabel("등락률")
ax2.set_ylabel("소비자 물가 지수")
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,10))
plt.xticks(rotation=90)

x = total_he_cpi_df.index
y = total_he_cpi_df["전국_의료/보건_등락률"]

ymin, ymax = plt.ylim([total_he_cpi_df["전국_의료/보건_등락률"].min(), total_he_cpi_df["전국_의료/보건_등락률"].max()])

plt.fill_between(x[0:4], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[3:7], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[6:10], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[9:13], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[12:16], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[15:19], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[18:22], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[21:25], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[24:28], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[27:31], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[30:34], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[33:37], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[36:40], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[39:43], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[42:46], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[45:49], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[48:52], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[51:55], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[54:58], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[57:], ymin, ymax, color='saddlebrown', alpha=0.5)

total_he_cpi_df["전국_의료/보건_등락률"].plot(color='black', marker='s', ax=ax1)

plt.title("전국_의료/보건_등락률")
plt.xlabel("날짜")
ax1.set_ylabel("등락률")
ax2.set_ylabel("소비자 물가 지수")
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,10))
plt.xticks(rotation=90)

x = total_he_cpi_df.index
y = total_he_cpi_df["전국_종합병원_등락률"]

ymin, ymax = plt.ylim([total_he_cpi_df["전국_종합병원_등락률"].min(), total_he_cpi_df["전국_종합병원_등락률"].max()])

plt.fill_between(x[0:4], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[3:7], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[6:10], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[9:13], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[12:16], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[15:19], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[18:22], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[21:25], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[24:28], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[27:31], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[30:34], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[33:37], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[36:40], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[39:43], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[42:46], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[45:49], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[48:52], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[51:55], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[54:58], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[57:], ymin, ymax, color='saddlebrown', alpha=0.5)

total_he_cpi_df["전국_종합병원_등락률"].plot(color='darkslateblue', marker='s', ax=ax1)

plt.title("전국_종합병원_등락률")
plt.xlabel("날짜")
ax1.set_ylabel("등락률")
ax2.set_ylabel("소비자 물가 지수")
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,10))
plt.xticks(rotation=90)

x = total_he_cpi_df.index
y = total_he_cpi_df["전국_일반병의원/기타의료기관_등락률"]

ymin, ymax = plt.ylim([total_he_cpi_df["전국_일반병의원/기타의료기관_등락률"].min(), total_he_cpi_df["전국_일반병의원/기타의료기관_등락률"].max()])

plt.fill_between(x[0:4], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[3:7], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[6:10], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[9:13], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[12:16], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[15:19], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[18:22], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[21:25], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[24:28], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[27:31], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[30:34], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[33:37], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[36:40], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[39:43], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[42:46], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[45:49], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[48:52], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[51:55], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[54:58], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[57:], ymin, ymax, color='saddlebrown', alpha=0.5)

total_he_cpi_df["전국_일반병의원/기타의료기관_등락률"].plot(color='darkslateblue', marker='s', ax=ax1)

plt.title("전국_일반병의원/기타의료기관_등락률")
plt.xlabel("날짜")
ax1.set_ylabel("등락률")
ax2.set_ylabel("소비자 물가 지수")
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,10))
plt.xticks(rotation=90)

x = total_gi_cpi_df.index
y = total_gi_cpi_df["전국_서적/문구_등락률"]

ymin, ymax = plt.ylim([total_gi_cpi_df["전국_서적/문구_등락률"].min(), total_gi_cpi_df["전국_서적/문구_등락률"].max()])

plt.fill_between(x[0:4], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[3:7], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[6:10], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[9:13], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[12:16], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[15:19], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[18:22], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[21:25], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[24:28], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[27:31], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[30:34], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[33:37], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[36:40], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[39:43], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[42:46], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[45:49], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[48:52], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[51:55], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[54:58], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[57:], ymin, ymax, color='saddlebrown', alpha=0.5)

total_gi_cpi_df["전국_서적/문구_등락률"].plot(color='darkslateblue', marker='s', ax=ax1)

plt.title("전국_서적/문구_등락률")
plt.xlabel("날짜")
ax1.set_ylabel("등락률")
ax2.set_ylabel("소비자 물가 지수")
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,10))
plt.xticks(rotation=90)

x = total_gi_cpi_df.index
y = total_gi_cpi_df["전국_교육_등락률"]

ymin, ymax = plt.ylim([total_gi_cpi_df["전국_교육_등락률"].min(), total_gi_cpi_df["전국_교육_등락률"].max()])

plt.fill_between(x[0:4], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[3:7], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[6:10], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[9:13], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[12:16], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[15:19], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[18:22], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[21:25], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[24:28], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[27:31], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[30:34], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[33:37], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[36:40], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[39:43], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[42:46], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[45:49], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[48:52], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[51:55], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[54:58], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[57:], ymin, ymax, color='saddlebrown', alpha=0.5)

total_gi_cpi_df["전국_교육_등락률"].plot(color='darkslateblue', marker='s', ax=ax1)

plt.title("전국_교육_등락률")
plt.xlabel("날짜")
ax1.set_ylabel("등락률")
ax2.set_ylabel("소비자 물가 지수")
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,10))
plt.xticks(rotation=90)

x = total_gi_cpi_df.index
y = total_gi_cpi_df["전국_공과금/개인 및 전문 서비스_등락률"]

ymin, ymax = plt.ylim([total_gi_cpi_df["전국_공과금/개인 및 전문 서비스_등락률"].min(), total_gi_cpi_df["전국_공과금/개인 및 전문 서비스_등락률"].max()])

plt.fill_between(x[0:4], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[3:7], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[6:10], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[9:13], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[12:16], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[15:19], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[18:22], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[21:25], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[24:28], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[27:31], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[30:34], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[33:37], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[36:40], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[39:43], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[42:46], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[45:49], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[48:52], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[51:55], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[54:58], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[57:], ymin, ymax, color='saddlebrown', alpha=0.5)

total_gi_cpi_df["전국_공과금/개인 및 전문 서비스_등락률"].plot(color='darkslateblue', marker='s', ax=ax1)

plt.title("전국_공과금/개인 및 전문 서비스_등락률")
plt.xlabel("날짜")
ax1.set_ylabel("등락률")
ax2.set_ylabel("소비자 물가 지수")
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,10))
plt.xticks(rotation=90)

x = total_gi_cpi_df.index
y = total_gi_cpi_df["전국_금융/보험_등락률"]

ymin, ymax = plt.ylim([total_gi_cpi_df["전국_금융/보험_등락률"].min(), total_gi_cpi_df["전국_금융/보험_등락률"].max()])

plt.fill_between(x[0:4], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[3:7], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[6:10], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[9:13], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[12:16], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[15:19], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[18:22], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[21:25], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[24:28], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[27:31], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[30:34], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[33:37], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[36:40], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[39:43], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[42:46], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[45:49], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[48:52], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[51:55], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[54:58], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[57:], ymin, ymax, color='saddlebrown', alpha=0.5)

total_gi_cpi_df["전국_금융/보험_등락률"].plot(color='darkslateblue', marker='s', ax=ax1)

plt.title("전국_금융/보험_등락률")
plt.xlabel("날짜")
ax1.set_ylabel("등락률")
ax2.set_ylabel("소비자 물가 지수")
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,10))
plt.xticks(rotation=90)

x = total_gi_cpi_df.index
y = total_gi_cpi_df["전국_기타_등락률"]

ymin, ymax = plt.ylim([total_gi_cpi_df["전국_기타_등락률"].min(), total_gi_cpi_df["전국_기타_등락률"].max()])

plt.fill_between(x[0:4], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[3:7], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[6:10], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[9:13], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[12:16], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[15:19], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[18:22], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[21:25], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[24:28], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[27:31], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[30:34], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[33:37], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[36:40], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[39:43], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[42:46], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[45:49], ymin, ymax, color='saddlebrown', alpha=0.5)
plt.fill_between(x[48:52], ymin, ymax, color='cyan', alpha=0.5)
plt.fill_between(x[51:55], ymin, ymax, color='forestgreen', alpha=0.5)
plt.fill_between(x[54:58], ymin, ymax, color='dodgerblue', alpha=0.5)
plt.fill_between(x[57:], ymin, ymax, color='saddlebrown', alpha=0.5)

total_gi_cpi_df["전국_기타_등락률"].plot(color='darkslateblue', marker='s', ax=ax1)

plt.title("전국_기타_등락률")
plt.xlabel("날짜")
ax1.set_ylabel("등락률")
ax2.set_ylabel("소비자 물가 지수")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
total_he_cpi_df['전국_건강보조식품_등락률'][total_he_cpi_df['계절']=='겨울'].plot(label = '겨울')
total_he_cpi_df['전국_건강보조식품_등락률'][total_he_cpi_df['계절']=='봄'].plot(label = '봄')
total_he_cpi_df['전국_건강보조식품_등락률'][total_he_cpi_df['계절']=='여름'].plot(label = '여름')
total_he_cpi_df['전국_건강보조식품_등락률'][total_he_cpi_df['계절']=='가을'].plot(label = '가을')
plt.legend()
plt.xlabel("날짜")
plt.show()

# %%
import numpy as np

np.std(total_he_cpi_df['전국_건강보조식품_등락률'][total_he_cpi_df['계절']=='겨울'])
# Out:
# 0.2587886310399967

# %%
np.std(total_he_cpi_df['전국_건강보조식품_등락률'][total_he_cpi_df['계절']=='봄'])
# Out:
# 0.15558480855488824

# %%
np.std(total_he_cpi_df['전국_건강보조식품_등락률'][total_he_cpi_df['계절']=='여름'])
# Out:
# 0.08025566785107593

# %%
np.std(total_he_cpi_df['전국_건강보조식품_등락률'][total_he_cpi_df['계절']=='가을'])
# Out:
# 0.405033434833883

# %%
np.std(total_he_cpi_df['전국_건강보조식품_등락률'][total_he_cpi_df['계절']=='가을'])
# Out:
# 0.405033434833883
